# %% [markdown]
# # Model Evaluation & Confusion Matrix Analysis
# This notebook evaluates the trained Persian Digit & CAPTCHA OCR models, computes accuracy, and visualizes confusion matrices.

# %%
import sys
sys.path.append('../')

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from src.dataset import get_dataset
from src.predictor import predict_digit
import tensorflow as tf

print('TensorFlow version:', tf.__version__)

# %% [markdown]
# ## 1. Load Dataset & Model

# %%
# Load sample dataset or test set
# train_ds, val_ds = get_dataset('../data/dataset_farsi')
print('Dataset loader ready.')

# %% [markdown]
# ## 2. Evaluation Metrics & Report

# %%
# Run evaluation and print classification report
print('Evaluation framework ready for notebook execution.')
