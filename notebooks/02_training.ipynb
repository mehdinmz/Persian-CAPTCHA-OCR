# %%
import sys
sys.path.append(os.path.abspath('..'))
from src.model import build_model
from src.dataset import get_dataset

# %%
model = build_model()
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
ds = get_dataset("../data/dataset_farsi")
# Out:
# Found 80000 files belonging to 10 classes.
# Using 56000 files for training.
# Found 80000 files belonging to 10 classes.
# Using 24000 files for validation.

# %%
len(ds[1])
# Out:
# 3000

# %%
model.fit(ds[0],validation_data=ds[1],epochs=5)
# Out:
# Epoch 1/5
# 7000/7000 ━━━━━━━━━━━━━━━━━━━━ 54s 8ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9942 - val_loss: 0.0272
# Epoch 2/5
# 7000/7000 ━━━━━━━━━━━━━━━━━━━━ 56s 8ms/step - accuracy: 0.9983 - loss: 0.0060 - val_accuracy: 0.9950 - val_loss: 0.0248
# Epoch 3/5
# 7000/7000 ━━━━━━━━━━━━━━━━━━━━ 56s 8ms/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 0.9952 - val_loss: 0.0262
# Epoch 4/5
# 7000/7000 ━━━━━━━━━━━━━━━━━━━━ 55s 8ms/step - accuracy: 0.9979 - loss: 0.0083 - val_accuracy: 0.9954 - val_loss: 0.0266
# Epoch 5/5
# 7000/7000 ━━━━━━━━━━━━━━━━━━━━ 56s 8ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9949 - val_loss: 0.0325

# %%
model.save("../models/digit_classifier5.keras")
